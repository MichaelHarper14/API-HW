# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json





# Import API key
import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
api_key = api_keys.api_key

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 606

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"''

CT_1 = requests.get(url)
CT_1_json = CT_1.json()
response_json =[]
lat = []
lng = []
temp = []
humidity = []
cloudiness = []
wind_speed = []
y = []


for x in cities: 
    try:
            
            params = {"appid" : api_key, "q" : x, "units" : "imperial"}
            response = requests.get(url, params= params).json()
            lat_value= response['coord']['lat']
            lng_value = response['coord']['lon']
            temp_value = response['main']['temp']
            humidity_value = response['main']['humidity']
            cloudiness_value = response['clouds']['all']
            wind_speed_value = response['wind']['speed']
            lat.append(response['coord']['lat'])
            temp.append(response['main']['temp'])
            humidity.append(response['main']['humidity'])
            cloudiness.append(response["clouds"]["all"])
            wind_speed.append(response['wind']['speed'])
            y.append(x)
           
          
        
    except (KeyError, IndexError):
        print(f':skip {x}')
# Out:
# :skip attawapiskat
# :skip pemangkat
# :skip lolua
# :skip karauzyak
# :skip asau
# :skip kismayo
# :skip belushya guba
# :skip chagda
# :skip kuche
# :skip barentsburg
# :skip afgoye
# :skip nizhneyansk
# :skip bolungarvik
# :skip taolanaro
# :skip mys shmidta
# :skip tsihombe
# :skip amderma
# :skip nguiu
# :skip grand river south east
# :skip ipora
# :skip vaitupu
# :skip kushmurun
# :skip rawannawi
# :skip kota bahru
# :skip bac lieu
# :skip illoqqortoormiut
# :skip sorvag
# :skip saleaula
# :skip ruatoria
# :skip skalistyy
# :skip korla
# :skip olafsvik
# :skip macaboboni
# :skip bengkulu
# :skip wulanhaote
# :skip artyk
# :skip louisbourg
# :skip barawe
# :skip toliary
# :skip karaul
# :skip el faiyum
# :skip galiwinku
# :skip palabuhanratu
# :skip abu jubayhah
# :skip sentyabrskiy
# :skip mutsamudu
# :skip gulshat
# :skip umzimvubu
# :skip dibaya
# :skip hunza
# :skip ngukurr
# :skip haibowan
# :skip samusu
# :skip naftah
# :skip grand centre
# :skip akyab

# %%
response_json =CT_1_json
response_json =[]

for x in range(len(cities)):
    print(f':Processing Record {x}:{cities[x]}')
# Out:
# :Processing Record 0:swellendam
# :Processing Record 1:upernavik
# :Processing Record 2:tamworth
# :Processing Record 3:lata
# :Processing Record 4:thompson
# :Processing Record 5:kavaratti
# :Processing Record 6:aksu
# :Processing Record 7:mount gambier
# :Processing Record 8:kohlu
# :Processing Record 9:punta arenas
# :Processing Record 10:bluff
# :Processing Record 11:attawapiskat
# :Processing Record 12:cape town
# :Processing Record 13:port elizabeth
# :Processing Record 14:leningradskiy
# :Processing Record 15:pemangkat
# :Processing Record 16:dikson
# :Processing Record 17:provideniya
# :Processing Record 18:hilo
# :Processing Record 19:carnarvon
# :Processing Record 20:salalah
# :Processing Record 21:avarua
# :Processing Record 22:santa cecilia
# :Processing Record 23:gazli
# :Processing Record 24:izmir
# :Processing Record 25:rikitea
# :Processing Record 26:samarai
# :Processing Record 27:saint-philippe
# :Processing Record 28:ushuaia
# :Processing Record 29:lolua
# :Processing Record 30:aykhal
# :Processing Record 31:karauzyak
# :Processing Record 32:severodvinsk
# :Processing Record 33:port lincoln
# :Processing Record 34:chokurdakh
# :Processing Record 35:papar
# :Processing Record 36:aklavik
# :Processing Record 37:inyonga
# :Processing Record 38:new norfolk
# :Processing Record 39:husavik
# :Processing Record 40:clyde river
# :Processing Record 41:ancud
# :Processing Record 42:bredasdorp
# :Processing Record 43:jamame
# :Processing Record 44:georgetown
# :Processing Record 45:ilulissat
# :Processing Record 46:rantepao
# :Processing Record 47:egvekinot
# :Processing Record 48:pevek
# :Processing Record 49:mataura
# :Processing Record 50:katsuura
# :Processing Record 51:bethel
# :Processing Record 52:mar del plata
# :Processing Record 53:san cristobal
# :Processing Record 54:petropavlovsk-kamchatskiy
# :Processing Record 55:iqaluit
# :Processing Record 56:jamestown
# :Processing Record 57:kaffrine
# :Processing Record 58:ailigandi
# :Processing Record 59:polunochnoye
# :Processing Record 60:tuatapere
# :Processing Record 61:mehamn
# :Processing Record 62:asau
# :Processing Record 63:hokitika
# :Processing Record 64:talara
# :Processing Record 65:sovetskiy
# :Processing Record 66:osorno
# :Processing Record 67:whitehorse
# :Processing Record 68:norman wells
# :Processing Record 69:kismayo
# :Processing Record 70:pisco
# :Processing Record 71:verkhnetulomskiy
# :Processing Record 72:butaritari
# :Processing Record 73:beyneu
# :Processing Record 74:ilebo
# :Processing Record 75:jadu
# :Processing Record 76:gat
# :Processing Record 77:kattivakkam
# :Processing Record 78:saskylakh
# :Processing Record 79:tiksi
# :Processing Record 80:belushya guba
# :Processing Record 81:qaanaaq
# :Processing Record 82:zemio
# :Processing Record 83:busselton
# :Processing Record 84:port-gentil
# :Processing Record 85:vaini
# :Processing Record 86:kupang
# :Processing Record 87:bud
# :Processing Record 88:kodiak
# :Processing Record 89:east london
# :Processing Record 90:saint george
# :Processing Record 91:buin
# :Processing Record 92:albany
# :Processing Record 93:klaksvik
# :Processing Record 94:sao filipe
# :Processing Record 95:kapaa
# :Processing Record 96:chagda
# :Processing Record 97:ust-tsilma
# :Processing Record 98:cherskiy
# :Processing Record 99:rockland
# :Processing Record 100:mount isa
# :Processing Record 101:hobart
# :Processing Record 102:kuche
# :Processing Record 103:barentsburg
# :Processing Record 104:kyaikkami
# :Processing Record 105:orchard homes
# :Processing Record 106:lagoa
# :Processing Record 107:touros
# :Processing Record 108:bathsheba
# :Processing Record 109:afgoye
# :Processing Record 110:batagay-alyta
# :Processing Record 111:pathein
# :Processing Record 112:tazovskiy
# :Processing Record 113:eureka
# :Processing Record 114:nizhneyansk
# :Processing Record 115:kruisfontein
# :Processing Record 116:bambous virieux
# :Processing Record 117:bolungarvik
# :Processing Record 118:taolanaro
# :Processing Record 119:nalut
# :Processing Record 120:medzev
# :Processing Record 121:san quintin
# :Processing Record 122:pauini
# :Processing Record 123:zalalovo
# :Processing Record 124:hermanus
# :Processing Record 125:saint-georges
# :Processing Record 126:rawson
# :Processing Record 127:yulara
# :Processing Record 128:nikolskoye
# :Processing Record 129:sao felix do xingu
# :Processing Record 130:ketchikan
# :Processing Record 131:garwa
# :Processing Record 132:nsanje
# :Processing Record 133:vanimo
# :Processing Record 134:mys shmidta
# :Processing Record 135:eyl
# :Processing Record 136:besuki
# :Processing Record 137:tuktoyaktuk
# :Processing Record 138:hay river
# :Processing Record 139:tsihombe
# :Processing Record 140:hueypoxtla
# :Processing Record 141:seoul
# :Processing Record 142:elizabeth city
# :Processing Record 143:bratsk
# :Processing Record 144:atuona
# :Processing Record 145:longyearbyen
# :Processing Record 146:ribeira grande
# :Processing Record 147:amga
# :Processing Record 148:puerto ayora
# :Processing Record 149:guarapari
# :Processing Record 150:lezajsk
# :Processing Record 151:alyangula
# :Processing Record 152:amderma
# :Processing Record 153:nguiu
# :Processing Record 154:dwarka
# :Processing Record 155:qaqortoq
# :Processing Record 156:padang
# :Processing Record 157:oktyabrskoye
# :Processing Record 158:karpogory
# :Processing Record 159:vanavara
# :Processing Record 160:saint-francois
# :Processing Record 161:zlobin
# :Processing Record 162:garchitorena
# :Processing Record 163:kuznechnoye
# :Processing Record 164:opuwo
# :Processing Record 165:boa vista
# :Processing Record 166:baykit
# :Processing Record 167:marawi
# :Processing Record 168:grand river south east
# :Processing Record 169:papillion
# :Processing Record 170:beira
# :Processing Record 171:faya
# :Processing Record 172:kaitangata
# :Processing Record 173:minot
# :Processing Record 174:lalmohan
# :Processing Record 175:hasaki
# :Processing Record 176:balikpapan
# :Processing Record 177:baruun-urt
# :Processing Record 178:hualmay
# :Processing Record 179:lorengau
# :Processing Record 180:chincholi
# :Processing Record 181:kidal
# :Processing Record 182:hamilton
# :Processing Record 183:mollendo
# :Processing Record 184:nokaneng
# :Processing Record 185:loa janan
# :Processing Record 186:ponta do sol
# :Processing Record 187:kathmandu
# :Processing Record 188:birin
# :Processing Record 189:zabol
# :Processing Record 190:torbat-e jam
# :Processing Record 191:yaan
# :Processing Record 192:chuy
# :Processing Record 193:port alfred
# :Processing Record 194:kavieng
# :Processing Record 195:dhidhdhoo
# :Processing Record 196:kita
# :Processing Record 197:north bend
# :Processing Record 198:noumea
# :Processing Record 199:hithadhoo
# :Processing Record 200:awbari
# :Processing Record 201:tasiilaq
# :Processing Record 202:san patricio
# :Processing Record 203:ipora
# :Processing Record 204:dalbandin
# :Processing Record 205:lasa
# :Processing Record 206:talnakh
# :Processing Record 207:strausberg
# :Processing Record 208:kutum
# :Processing Record 209:vaitupu
# :Processing Record 210:kushmurun
# :Processing Record 211:atherton
# :Processing Record 212:jurm
# :Processing Record 213:ilmajoki
# :Processing Record 214:natal
# :Processing Record 215:castro
# :Processing Record 216:tessalit
# :Processing Record 217:lerwick
# :Processing Record 218:paamiut
# :Processing Record 219:beloha
# :Processing Record 220:pokosnoye
# :Processing Record 221:torbay
# :Processing Record 222:tiarei
# :Processing Record 223:port hedland
# :Processing Record 224:whitefish
# :Processing Record 225:staryy nadym
# :Processing Record 226:yerbogachen
# :Processing Record 227:prince rupert
# :Processing Record 228:araxa
# :Processing Record 229:airai
# :Processing Record 230:margate
# :Processing Record 231:upington
# :Processing Record 232:barrow
# :Processing Record 233:edd
# :Processing Record 234:kieta
# :Processing Record 235:saldanha
# :Processing Record 236:cayenne
# :Processing Record 237:lufkin
# :Processing Record 238:codrington
# :Processing Record 239:jackson
# :Processing Record 240:vila velha
# :Processing Record 241:lebu
# :Processing Record 242:flinders
# :Processing Record 243:peniche
# :Processing Record 244:los llanos de aridane
# :Processing Record 245:kilindoni
# :Processing Record 246:yarmouth
# :Processing Record 247:fortuna
# :Processing Record 248:ostrovnoy
# :Processing Record 249:shaygino
# :Processing Record 250:dunedin
# :Processing Record 251:gidole
# :Processing Record 252:conde
# :Processing Record 253:henties bay
# :Processing Record 254:rawannawi
# :Processing Record 255:ambajogai
# :Processing Record 256:purworejo
# :Processing Record 257:varhaug
# :Processing Record 258:murashi
# :Processing Record 259:kumluca
# :Processing Record 260:guerrero negro
# :Processing Record 261:lazaro cardenas
# :Processing Record 262:kota bahru
# :Processing Record 263:karsava
# :Processing Record 264:buchanan
# :Processing Record 265:samana
# :Processing Record 266:kigoma
# :Processing Record 267:kalmunai
# :Processing Record 268:fairbanks
# :Processing Record 269:slovenske konjice
# :Processing Record 270:port hardy
# :Processing Record 271:tokur
# :Processing Record 272:bac lieu
# :Processing Record 273:illoqqortoormiut
# :Processing Record 274:barwani
# :Processing Record 275:salekhard
# :Processing Record 276:lompoc
# :Processing Record 277:grindavik
# :Processing Record 278:manacor
# :Processing Record 279:shubarshi
# :Processing Record 280:wana
# :Processing Record 281:nizwa
# :Processing Record 282:sydney
# :Processing Record 283:esperance
# :Processing Record 284:seymchan
# :Processing Record 285:yatou
# :Processing Record 286:kulhudhuffushi
# :Processing Record 287:sorvag
# :Processing Record 288:haines junction
# :Processing Record 289:russell
# :Processing Record 290:vao
# :Processing Record 291:mae hong son
# :Processing Record 292:tungor
# :Processing Record 293:treinta y tres
# :Processing Record 294:hovd
# :Processing Record 295:geraldton
# :Processing Record 296:aksarka
# :Processing Record 297:babusnica
# :Processing Record 298:brigantine
# :Processing Record 299:ukiah
# :Processing Record 300:palmer
# :Processing Record 301:gizo
# :Processing Record 302:tocantins
# :Processing Record 303:bonavista
# :Processing Record 304:ostersund
# :Processing Record 305:nushki
# :Processing Record 306:porto novo
# :Processing Record 307:mackenzie
# :Processing Record 308:victoria
# :Processing Record 309:kokopo
# :Processing Record 310:avera
# :Processing Record 311:galich
# :Processing Record 312:caravelas
# :Processing Record 313:novyy urengoy
# :Processing Record 314:yellowknife
# :Processing Record 315:taketa
# :Processing Record 316:nelson bay
# :Processing Record 317:ocher
# :Processing Record 318:alofi
# :Processing Record 319:parasia
# :Processing Record 320:saint-augustin
# :Processing Record 321:westport
# :Processing Record 322:saleaula
# :Processing Record 323:srednekolymsk
# :Processing Record 324:vila
# :Processing Record 325:arraial do cabo
# :Processing Record 326:ruatoria
# :Processing Record 327:alibag
# :Processing Record 328:amapa
# :Processing Record 329:orzhytsya
# :Processing Record 330:nemuro
# :Processing Record 331:puerto leguizamo
# :Processing Record 332:tsabong
# :Processing Record 333:kasongo-lunda
# :Processing Record 334:ardakan
# :Processing Record 335:evanston
# :Processing Record 336:isangel
# :Processing Record 337:chapais
# :Processing Record 338:karratha
# :Processing Record 339:atar
# :Processing Record 340:ambilobe
# :Processing Record 341:slobodskoy
# :Processing Record 342:west bay
# :Processing Record 343:lashio
# :Processing Record 344:skalistyy
# :Processing Record 345:hofn
# :Processing Record 346:korla
# :Processing Record 347:nantucket
# :Processing Record 348:ponta delgada
# :Processing Record 349:olafsvik
# :Processing Record 350:metro
# :Processing Record 351:macaboboni
# :Processing Record 352:bindki
# :Processing Record 353:maravilha
# :Processing Record 354:merrill
# :Processing Record 355:nipawin
# :Processing Record 356:maralal
# :Processing Record 357:comodoro rivadavia
# :Processing Record 358:sola
# :Processing Record 359:bagnara calabra
# :Processing Record 360:dauriya
# :Processing Record 361:bengkulu
# :Processing Record 362:francistown
# :Processing Record 363:dillon
# :Processing Record 364:tanete
# :Processing Record 365:wulanhaote
# :Processing Record 366:dingle
# :Processing Record 367:wundanyi
# :Processing Record 368:riachao das neves
# :Processing Record 369:birjand
# :Processing Record 370:camocim
# :Processing Record 371:klaipeda
# :Processing Record 372:erdemli
# :Processing Record 373:borogontsy
# :Processing Record 374:artyk
# :Processing Record 375:hollins
# :Processing Record 376:quesnel
# :Processing Record 377:idaho falls
# :Processing Record 378:maniitsoq
# :Processing Record 379:miri
# :Processing Record 380:louisbourg
# :Processing Record 381:buraydah
# :Processing Record 382:luebo
# :Processing Record 383:cape coast
# :Processing Record 384:sisimiut
# :Processing Record 385:tacna
# :Processing Record 386:simpang
# :Processing Record 387:lamu
# :Processing Record 388:brae
# :Processing Record 389:bulawayo
# :Processing Record 390:taoudenni
# :Processing Record 391:lucapa
# :Processing Record 392:talavera de la reina
# :Processing Record 393:blackwater
# :Processing Record 394:matagami
# :Processing Record 395:broome
# :Processing Record 396:bereda
# :Processing Record 397:barawe
# :Processing Record 398:yar-sale
# :Processing Record 399:pratapgarh
# :Processing Record 400:letnik
# :Processing Record 401:kampot
# :Processing Record 402:kandi
# :Processing Record 403:voi
# :Processing Record 404:rosarito
# :Processing Record 405:faanui
# :Processing Record 406:port-cartier
# :Processing Record 407:namibe
# :Processing Record 408:rockport
# :Processing Record 409:toliary
# :Processing Record 410:trelew
# :Processing Record 411:khatanga
# :Processing Record 412:nagram
# :Processing Record 413:karaul
# :Processing Record 414:saint-joseph
# :Processing Record 415:virginia beach
# :Processing Record 416:les cayes
# :Processing Record 417:el faiyum
# :Processing Record 418:coihaique
# :Processing Record 419:zeya
# :Processing Record 420:galiwinku
# :Processing Record 421:palabuhanratu
# :Processing Record 422:cidreira
# :Processing Record 423:port augusta
# :Processing Record 424:betare oya
# :Processing Record 425:sinnamary
# :Processing Record 426:teguise
# :Processing Record 427:camacha
# :Processing Record 428:abu jubayhah
# :Processing Record 429:sentyabrskiy
# :Processing Record 430:ozernovskiy
# :Processing Record 431:cabo san lucas
# :Processing Record 432:liepaja
# :Processing Record 433:vardo
# :Processing Record 434:fort nelson
# :Processing Record 435:bandrele
# :Processing Record 436:huaicheng
# :Processing Record 437:portland
# :Processing Record 438:steamboat springs
# :Processing Record 439:el tarra
# :Processing Record 440:waipawa
# :Processing Record 441:kropotkin
# :Processing Record 442:kamenka
# :Processing Record 443:dongsheng
# :Processing Record 444:bambanglipuro
# :Processing Record 445:sao joao da barra
# :Processing Record 446:puerto suarez
# :Processing Record 447:saryg-sep
# :Processing Record 448:batemans bay
# :Processing Record 449:kindu
# :Processing Record 450:abu samrah
# :Processing Record 451:itarema
# :Processing Record 452:gornyak
# :Processing Record 453:lufilufi
# :Processing Record 454:ulaanbaatar
# :Processing Record 455:mao
# :Processing Record 456:lixourion
# :Processing Record 457:manicore
# :Processing Record 458:tawang
# :Processing Record 459:nampula
# :Processing Record 460:banda aceh
# :Processing Record 461:abbeyfeale
# :Processing Record 462:stonewall
# :Processing Record 463:nuuk
# :Processing Record 464:vila franca do campo
# :Processing Record 465:talakan
# :Processing Record 466:bhalki
# :Processing Record 467:coahuayana
# :Processing Record 468:sunndalsora
# :Processing Record 469:kyabe
# :Processing Record 470:mogwase
# :Processing Record 471:nabire
# :Processing Record 472:mandera
# :Processing Record 473:manggar
# :Processing Record 474:samfya
# :Processing Record 475:burewala
# :Processing Record 476:vallenar
# :Processing Record 477:vangaindrano
# :Processing Record 478:vagur
# :Processing Record 479:kharovsk
# :Processing Record 480:beringovskiy
# :Processing Record 481:teya
# :Processing Record 482:jeannette
# :Processing Record 483:northam
# :Processing Record 484:yeniseysk
# :Processing Record 485:mutsamudu
# :Processing Record 486:tigil
# :Processing Record 487:la libertad
# :Processing Record 488:islamkot
# :Processing Record 489:constitucion
# :Processing Record 490:lavrentiya
# :Processing Record 491:megion
# :Processing Record 492:zaozerne
# :Processing Record 493:mahibadhoo
# :Processing Record 494:bridlington
# :Processing Record 495:san fernando
# :Processing Record 496:port macquarie
# :Processing Record 497:ferme-neuve
# :Processing Record 498:bonthe
# :Processing Record 499:atambua
# :Processing Record 500:grand gaube
# :Processing Record 501:karasjok
# :Processing Record 502:wheeling
# :Processing Record 503:nishihara
# :Processing Record 504:shingu
# :Processing Record 505:scarborough
# :Processing Record 506:harper
# :Processing Record 507:sobolevo
# :Processing Record 508:gulshat
# :Processing Record 509:omboue
# :Processing Record 510:adrar
# :Processing Record 511:kazachinskoye
# :Processing Record 512:roma
# :Processing Record 513:maba
# :Processing Record 514:mahebourg
# :Processing Record 515:umzimvubu
# :Processing Record 516:dibaya
# :Processing Record 517:tekeli
# :Processing Record 518:kadaya
# :Processing Record 519:luanda
# :Processing Record 520:hunza
# :Processing Record 521:forestville
# :Processing Record 522:kefamenanu
# :Processing Record 523:ngukurr
# :Processing Record 524:mareeba
# :Processing Record 525:jeremie
# :Processing Record 526:gorin
# :Processing Record 527:stantsionno-oyashinskiy
# :Processing Record 528:novyy nekouz
# :Processing Record 529:santiago
# :Processing Record 530:bandarbeyla
# :Processing Record 531:severo-kurilsk
# :Processing Record 532:zonguldak
# :Processing Record 533:quatre cocos
# :Processing Record 534:nogales
# :Processing Record 535:haibowan
# :Processing Record 536:sinjai
# :Processing Record 537:te anau
# :Processing Record 538:phalaborwa
# :Processing Record 539:amahai
# :Processing Record 540:sabla
# :Processing Record 541:namatanai
# :Processing Record 542:shihezi
# :Processing Record 543:vestmannaeyjar
# :Processing Record 544:mahasamund
# :Processing Record 545:rassvet
# :Processing Record 546:sitka
# :Processing Record 547:mikuni
# :Processing Record 548:katherine
# :Processing Record 549:turhal
# :Processing Record 550:mayo
# :Processing Record 551:santa maria
# :Processing Record 552:samusu
# :Processing Record 553:chandbali
# :Processing Record 554:tambacounda
# :Processing Record 555:farah
# :Processing Record 556:gold coast
# :Processing Record 557:santiago de cao
# :Processing Record 558:honiara
# :Processing Record 559:verkhoturye
# :Processing Record 560:tual
# :Processing Record 561:ahvaz
# :Processing Record 562:guaymas
# :Processing Record 563:tilichiki
# :Processing Record 564:naftah
# :Processing Record 565:grand centre
# :Processing Record 566:nardaran
# :Processing Record 567:ribeira brava
# :Processing Record 568:araouane
# :Processing Record 569:thinadhoo
# :Processing Record 570:kirkwall
# :Processing Record 571:edea
# :Processing Record 572:jalu
# :Processing Record 573:nanyamba
# :Processing Record 574:biak
# :Processing Record 575:warrington
# :Processing Record 576:pangody
# :Processing Record 577:bonneville
# :Processing Record 578:oranjestad
# :Processing Record 579:nanakuli
# :Processing Record 580:sovetskaya gavan
# :Processing Record 581:christchurch
# :Processing Record 582:taltal
# :Processing Record 583:akyab
# :Processing Record 584:tangermunde
# :Processing Record 585:kununurra
# :Processing Record 586:kastamonu
# :Processing Record 587:sumoto
# :Processing Record 588:barnstaple
# :Processing Record 589:ayan
# :Processing Record 590:gananoque
# :Processing Record 591:mwinilunga
# :Processing Record 592:taveta
# :Processing Record 593:kangaatsiaq
# :Processing Record 594:santa vitoria do palmar
# :Processing Record 595:pozo colorado
# :Processing Record 596:sidney
# :Processing Record 597:keti bandar
# :Processing Record 598:fougamou
# :Processing Record 599:correntina
# :Processing Record 600:yamada
# :Processing Record 601:strathmore
# :Processing Record 602:poso
# :Processing Record 603:granville
# :Processing Record 604:bull savanna
# :Processing Record 605:tecoanapa

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"''
query_url = f"{url}appid={api_key}&q={city}"
CT_1 = requests.get(query_url)
CT_1_json = CT_1.json()

response_json
# Out:
# []

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
city_data = pd.DataFrame({"Cities": y, "Latitude": lat,  "Temperature": temp, "Humidity": humidity, "Cloudiness": cloudiness, "WindSpeed(MPH)": wind_speed})

city_data["Humidity"] = city_data["Humidity"].map("{}%".format)
city_data["Cloudiness"] = city_data["Cloudiness"].map("{}%".format)
city_data.head()
# Out:
#        Cities  Latitude  Temperature Humidity Cloudiness  WindSpeed(MPH)
# 0  swellendam    -34.02        55.40      66%         0%            3.36
# 1   upernavik     72.79        43.55      82%         0%           10.63
# 2    tamworth    -31.09        58.68      62%         0%            5.82
# 3        lata     30.78        40.85      86%         7%            2.53
# 4    thompson     55.74        84.20      30%        75%            9.17

# %%
city_data.to_csv("city_data.csv", encoding="utf-8", index=False)

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(lat, temp, marker="o")

# Incorporate the other graph properties
plt.title("Distribution of Temperature by latitude")
plt.ylabel("Temperature (Farenheit)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("Temp_Scat.png")

# Show plot

plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(lat, humidity, marker="o")

# Incorporate the other graph properties
plt.title("Distribution of Humidity by latitude")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("Humidity_Scat.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(lat, wind_speed, marker="o")

# Incorporate the other graph properties
plt.title("Distribution of Wind Speed by latitude")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Windspeed_Scat.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(lat, cloudiness, marker="o")

# Incorporate the other graph properties
plt.title("Distribution of Cloudiness by latitude")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure

plt.savefig("Cloudiness_Scat.png")
# Show plot
plt.show()
